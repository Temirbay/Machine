# %%
import matplotlib.pyplot as plt
import os
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import collections
import math
import numpy as np
from numpy import linalg as LA
import plotly.plotly as py
#Initializing variables
all_text = ""
all_words = ""
mydict = {}
all_indexes = {}
all_one_hot_vectors = []
all_vector = []
dicts = []

files = os.listdir("./dataset")
number_of_datasets = len(files)

print ("number of datasets: " + str(number_of_datasets))



#Get text and words from all datasets
cnt = 1
while cnt <= number_of_datasets:
    path = './dataset/resume' + str(cnt) + '.txt'
    file = open(path, 'r').read()
    all_text += file
    cnt = cnt + 1

all_words = word_tokenize(all_text)
all_words = set(all_words)
all_words = sorted (all_words)

cnt = 1
for word in all_words:
    all_indexes[word] = cnt;
    cnt = cnt + 1

#Building a dictionary from words from text
for word in all_words:
    mydict[word] = 0
for word in all_words:
    mydict[word] += 1

    
    
#Building a list of dictionaries from all files
cnt = 1
while cnt <= number_of_datasets:
    path = './dataset/resume' + str(cnt) + '.txt'
    file = open(path, 'r').read()
    
    all_words_in_file = word_tokenize(file)
    all_words_in_file = set(all_words_in_file)
    all_words_in_file = sorted(all_words_in_file)
    
    temp_dicts = {}
    myvector = []
    
    for word in all_words:
        temp_dicts[word] = 0
    
    for word in all_words_in_file:
        if word in all_words:
            temp_dicts[word] += 1
    
    for word in all_words:
        if word in all_words_in_file:
            myvector.append(temp_dicts[word])
        else:
            myvector.append(0)
    
    dicts.append(temp_dicts)
    all_vector.append(myvector)
    
    # Building one-hot encoding vectors
    myvector = []
    for word in all_words:
        if word in all_words_in_file:
            myvector.append(all_indexes[word])
        else:
            myvector.append(0)
        
    all_one_hot_vectors.append(myvector)
    
    cnt = cnt + 1

    
#Building distance between all vectors

def scalar_product(vect1, vect2):
    product = 0
    for i in range(len(vect1)):
        product += (vect1[i] * vect2[i])
    
    return product;

def length_of_vector(vect):
    num = 0
    for i in range(len(vect)):
        num += (vect[i] * vect[i])
    return math.sqrt(num)


distances = []
for i in range(number_of_datasets):
    distances.append([])
    
for i in range(number_of_datasets):
    for j in range(number_of_datasets):
        num = 0
        p = scalar_product(all_one_hot_vectors[i], all_one_hot_vectors[j])
        l1 = length_of_vector(all_one_hot_vectors[i])
        l2 = length_of_vector(all_one_hot_vectors[j])
        num = p / (l1 * l2)
        distances[i].append(round(num, 5))
        
#Building 
def find(eps):
    adj = []
    degrees = []
    laplace = []
    
    for i in range(number_of_datasets):
        adj.append([])
        laplace.append([])

    # Building adjacency table
    for i in range(number_of_datasets):
        for j in range(number_of_datasets):
            if (distances[i][j] >= eps):
                adj[i].append(1)
            else:
                adj[i].append(0)
    
    # Building degree vector
    for i in range(number_of_datasets):
        degrees.append(0)
        for j in range(number_of_datasets):
            degrees[i] += adj[i][j]

    #Building laplace table
    for i in range(number_of_datasets):
        for j in range(number_of_datasets):
            if (i == j):
                laplace[i].append(degrees[i])
            elif(adj[i][j] == 1):
                laplace[i].append(-1)
            else:
                laplace[i].append(0)
                
    y = np.array([np.array(xi) for xi in laplace])
    v = LA.eig(y)
    plt.hist(v[0])
    plt.title("Gaussian Histogram")
    plt.xlabel("Value")
    plt.ylabel("Frequency")

    fig = plt.gcf()

    plot_url = py.plot_mpl(fig, filename='mpl-basic-histogram')

find (0.3)
# Out:
# number of datasets: 50
# C:\Users\Miras\Anaconda3\lib\site-packages\numpy\lib\function_base.py:754: ComplexWarning: Casting complex values to real discards the imaginary part
#   tmp_a_data = tmp_a.astype(float)
# C:\Users\Miras\Anaconda3\lib\site-packages\numpy\lib\function_base.py:760: ComplexWarning: Casting complex values to real discards the imaginary part
#   indices = tmp_a.astype(np.intp)
# C:\Users\Miras\Anaconda3\lib\site-packages\matplotlib\patches.py:690: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._x = float(xy[0])
# C:\Users\Miras\Anaconda3\lib\site-packages\matplotlib\patches.py:692: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._width = float(width)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b364d29b7f50> in <module>()
#     165     plot_url = py.plot_mpl(fig, filename='mpl-basic-histogram')
#     166
# --> 167 find (0.3)
#
# <ipython-input-36-b364d29b7f50> in find(eps)
#     163     fig = plt.gcf()
#     164
# --> 165     plot_url = py.plot_mpl(fig, filename='mpl-basic-histogram')
#     166
#     167 find (0.3)
#
# NameError: name 'py' is not defined
